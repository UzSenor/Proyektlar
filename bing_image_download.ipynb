# %%
! pip install bing_image_downloader

# %%
from bing_image_downloader import downloader
downloader.download("with_mask", limit=1000,  output_dir='data')
# Out:
# [%] Downloading Images to C:\Users\DNS\Desktop\ZOOM\data\with_mask
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://wallpapercave.com/wp/wp7668108.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wallpapercave.com/wp/wp6768300.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.hdwallpapers.in/download/xiao_with_mask_on_face_hd_genshin_impact-1280x720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.vox-cdn.com/thumbor/8NFJyrxa4tPn0uRR13Rahv1zYOU=/0x0:1214x809/1200x800/filters:focal(0x0:1214x809)/cdn.vox-cdn.com/uploads/chorus_image/image/32665529/urme.0.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.corrections.com/system/article/image/21759/man-in-mask.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://bestlifeonline.com/wp-content/uploads/sites/3/2021/01/masking-1.jpg?quality=82&amp;strip=1&amp;resize=970%2C546
# ...

# %%
# !pip install pillow
